# %%
from Secos import Decomposition
from Secos.models import german_model
# Out:
# /Users/mathiashaugestad/opt/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
d = Decomposition('Bundesfinanzministerium', german_model)

# %%
d.decompose()
# Out:
# ['Bundes', 'finanz', 'ministerium']

# %%
d.__dict__
# Out:
# {'word': 'Bundesfinanzministerium',
#  'ml': 3,
#  'model': DecompoundingModel(German, n_words=366015, total_wordcount=576816574, epsilon=0.001),
#  'compounds': [Compounds(generated dictionary, Bundes,finanz,ministerium, p=4.012580346153608e-08),
#   Compounds(generated dictionary, Bunde,sfinanz,ministerium, p=2.474534487160905e-10)],
#  'similar_candidates': ['finanzministerium'],
#  'extended_similar_candidates': [],
#  'generated_dictionary': ['Bundes',
#   'minister',
#   'Bundesfinanzministerium',
#   'Bundesfinanzminister',
#   'Bundesfinanz',
#   'Bunde',
#   'finanz'],
#  'methods': [Method(generated dictionary)]}

# %%
d.decompose()
# Out:
# ['Bundesfinanzministerium']

# %%
c = d.compounds[1]

# %%
d.compounds
# Out:
# [Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#  Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#  Compounds(similar candidates, Bundes,finanzministerium, p=1.0578688929960953e-08),
#  Compounds(similar candidates, Bundes,finanzministerium, p=1.0578688929960953e-08)]

# %%
d.__dict__
# Out:
# {'word': 'Bundesfinanzministerium',
#  'ml': 3,
#  'model': DecompoundingModel(German, n_words=366015, total_wordcount=576816574, epsilon=0.001),
#  'compounds': [Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(similar candidates, Bundes,finanzministerium, p=1.0578688929960953e-08),
#   Compounds(similar candidates, Bundes,finanzministerium, p=1.0578688929960953e-08)],
#  'similar_candidates': ['finanzministerium'],
#  'extended_similar_candidates': [],
#  'generated_dictionary': ['00.10',
#   '000er',
#   '00:36',
#   '01.07.2010',
#   '06.02.2009',
#   '07:20',
#   '08:29',
#   '1.280',
#   '10,11',
#   '10,48',
#   '10-jähriges',
#   '1024x600',
#   '104.6',
#   '105,7',
#   '117.000',
#   '12,82',
#   '127,3',
#   '12:33',
#   '13,54',
#   '13:05',
#   '14,26',
#   '14-köpfige',
#   '15.50',
#   '15.500',
#   '1500-m-Rennen',
# ...

# %%
set(chain.from_iterable([(0,7),(6, 23)] + [(0, 24)]))
# Out:
# {0, 6, 7, 23, 24}

# %%
d.methods[0].__dict__
# Out:
# {'name': 'similar candidates',
#  'candidate_spans': [(6, 23)],
#  'candidates': {'finanzministerium'},
#  'splits': [0, 6, 23],
#  'ml': 3,
#  'suffix_prefix': [0, 6],
#  'prefix_suffix': [0, 6]}

# %%
d.__dict__
# Out:
# {'word': 'Bundesfinanzministerium',
#  'ml': 3,
#  'model': DistributionalThesaurus(German, n_words=366015, total_wordcount=576816574, epsilon=0.001),
#  'compounds': [Compounds(similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(extended similar candidates, Bundesfinanzministerium, p=1.2626191248493175e-05),
#   Compounds(generated dictionary, Bundes,finanz,ministerium, p=4.012580346153608e-08),
#   Compounds(generated dictionary, Bunde,sfinanz,ministerium, p=2.474534487160905e-10)],
#  'similar_candidates': ['finanzministerium'],
#  'extended_similar_candidates': ['wissenschaftsministerium',
#   'bundesumwelt-',
#   'außenamt',
#   'vroutsis',
#   'schuldenmanagement',
#   'finanzministeriums',
#   'arbeitsministeriums',
#   'umstrukturierungsplan',
# ...
